# %%
# %pylab inline
import seaborn as sns
import pandas as pd

sns.set_style('darkgrid')
sns.set(font_scale=1.5)
# Out:
# %pylab is deprecated, use %matplotlib inline and import the required libraries.
# Populating the interactive namespace from numpy and matplotlib

# %%
url="https://econdata.s3-us-west-2.amazonaws.com/Reports/Core/RDC_Inventory_Core_Metrics_Zip_History.csv"

df=pd.read_csv(url)
# Out:
# C:\Users\chris\AppData\Local\Temp\ipykernel_8412\3319454315.py:3: DtypeWarning: Columns (0,1) have mixed types. Specify dtype option on import or set low_memory=False.
#   df=pd.read_csv(url)

# %%
df['year']=df['month_date_yyyymm'].astype(str).str[:4]
df['month']=df['month_date_yyyymm'].astype(str).str[4:6]

df['year']=pd.to_numeric(df['year'],errors='coerce')
df['month']=pd.to_numeric(df['month'],errors='coerce')

df['date']=pd.to_datetime(df[['year', 'month']].assign(DAY=1))

# %%
toga=df[df['zip_name']=="saratoga springs, ny"]
#.query('zip_name == "saratoga springs, ny”')

# %%
data=toga
y='median_listing_price_per_square_foot'

sns.lineplot(data=data,x='date',y=y)
fig = mpl.pyplot.gcf()
fig.set_size_inches(15,9.5)
plt.xticks(rotation=60)
plt.title("Saratoga " + y+' (source: Realtor.com)')
# Out:
# Text(0.5, 1.0, 'Saratoga median_listing_price_per_square_foot (source: Realtor.com)')

# %%
toga.columns
# Out:
# Index(['month_date_yyyymm', 'postal_code', 'zip_name', 'median_listing_price',
#        'median_listing_price_mm', 'median_listing_price_yy',
#        'active_listing_count', 'active_listing_count_mm',
#        'active_listing_count_yy', 'median_days_on_market',
#        'median_days_on_market_mm', 'median_days_on_market_yy',
#        'new_listing_count', 'new_listing_count_mm', 'new_listing_count_yy',
#        'price_increased_count', 'price_increased_count_mm',
#        'price_increased_count_yy', 'price_reduced_count',
#        'price_reduced_count_mm', 'price_reduced_count_yy',
#        'pending_listing_count', 'pending_listing_count_mm',
#        'pending_listing_count_yy', 'median_listing_price_per_square_foot',
#        'median_listing_price_per_square_foot_mm',
#        'median_listing_price_per_square_foot_yy', 'median_square_feet',
#        'median_square_feet_mm', 'median_square_feet_yy',
#        'average_listing_price', 'average_listing_price_mm',
# ...

# %%
data=toga
data['year']=pd.to_numeric(data['year'],errors='coerce')
data=toga.query('year > 2016')
# data['year']=data['year'].astype(str)
sns.lineplot(data=data,x='month',y='median_listing_price_per_square_foot',hue='year',legend='full',palette='tab10')
#move legend outside of plot
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
fig = mpl.pyplot.gcf()
fig.set_size_inches(13,8.5)
plt.title('Saratoga Median Listing Price Per Square Foot (source: Realtor.com)')
# Out:
# C:\Users\chris\AppData\Local\Temp\ipykernel_8412\3854571339.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['year']=pd.to_numeric(data['year'],errors='coerce')
# Text(0.5, 1.0, 'Saratoga Median Listing Price Per Square Foot (source: Realtor.com)')

# %%
data=toga
data['year']=pd.to_numeric(data['year'],errors='coerce')
data=toga.query('year > 2016')
# data['year']=data['year'].astype(str)
sns.lineplot(data=data,x='month',y='median_days_on_market',hue='year',legend='full',palette='tab10')
#move legend outside of plot
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
fig = mpl.pyplot.gcf()
fig.set_size_inches(13,8.5)
plt.title('Saratoga Median Days on Market (source: Realtor.com)')
# Out:
# C:\Users\chris\AppData\Local\Temp\ipykernel_8412\917688404.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['year']=pd.to_numeric(data['year'],errors='coerce')
# Text(0.5, 1.0, 'Saratoga Median Days on Market (source: Realtor.com)')

# %%
data=toga
data['year']=pd.to_numeric(data['year'],errors='coerce')
data=toga.query('year > 2016')
# data['year']=data['year'].astype(str)
sns.lineplot(data=data,x='month',y='active_listing_count',hue='year',legend='full',palette='tab10')
#move legend outside of plot
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
fig = mpl.pyplot.gcf()
fig.set_size_inches(13,8.5)
plt.title('Saratoga Active Listing Count (source: Realtor.com)')
# Out:
# C:\Users\chris\AppData\Local\Temp\ipykernel_8412\102636809.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['year']=pd.to_numeric(data['year'],errors='coerce')
# Text(0.5, 1.0, 'Saratoga Active Listing Count (source: Realtor.com)')

# %%
data=toga
y='active_listing_count'

sns.lineplot(data=data,x='date',y=y)
fig = mpl.pyplot.gcf()
fig.set_size_inches(15,9.5)
plt.xticks(rotation=60)
plt.title("Saratoga " + y+' (source: Realtor.com)')
# Out:
# Text(0.5, 1.0, 'Saratoga active_listing_count (source: Realtor.com)')

# %%
toga.dtypes
# Out:
# month_date_yyyymm                                  object
# postal_code                                        object
# zip_name                                           object
# median_listing_price                              float64
# median_listing_price_mm                           float64
# median_listing_price_yy                           float64
# active_listing_count                              float64
# active_listing_count_mm                           float64
# active_listing_count_yy                           float64
# median_days_on_market                             float64
# median_days_on_market_mm                          float64
# median_days_on_market_yy                          float64
# new_listing_count                                 float64
# new_listing_count_mm                              float64
# new_listing_count_yy                              float64
# price_increased_count                             float64
# ...

# %%
toga['year'].unique()
# Out:
# array([2023., 2022., 2021., 2020., 2019., 2018., 2017., 2016.])

# %%
df2=df.query('zip_name == ["savannah, ga",]') #

# %%
data=df2
y='median_listing_price_per_square_foot'

sns.lineplot(data=data,x='date',y=y,hue='postal_code',)
fig = mpl.pyplot.gcf()
fig.set_size_inches(15,9.5)
plt.xticks(rotation=60)
plt.title("Realtor.com " + y)
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)

# %%
data=df.query('postal_code == 31401')
y='median_listing_price_per_square_foot'

sns.lineplot(data=data,x='date',y=y,hue='postal_code',color='black')
fig = mpl.pyplot.gcf()
fig.set_size_inches(15,9.5)
plt.xticks(rotation=60)
plt.title("Realtor.com " + y)
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)

# %%
df.query('postal_code == 31401')
# Out:
#          month_date_yyyymm  postal_code      zip_name  median_listing_price  \
# 12427               202207        31401  savannah, ga              749000.0
# 53857               202206        31401  savannah, ga              750000.0
# 81679               202205        31401  savannah, ga              755000.0
# 101399              202204        31401  savannah, ga              875000.0
# 113383              202203        31401  savannah, ga              818170.0
# ...                    ...          ...           ...                   ...
# 1894593             201611        31401  savannah, ga              339000.0
# 1908394             201610        31401  savannah, ga              340000.0
# 1922968             201609        31401  savannah, ga              349900.0
# 1938285             201608        31401  savannah, ga              349999.0
# 1974453             201607        31401  savannah, ga              385000.0
#
# ...

# %%
a='12866'
df.query("postal_code == @a")
# Out:
# C:\Users\chris\anaconda3\lib\site-packages\numpy\lib\arraysetops.py:583: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   mask |= (ar1 == a)
# Empty DataFrame
# ...

# %%
a
# Out:
# '12866'

# %%
df=df.dropna(subset=['postal_code'])
df[df.postal_code.str.contains('12866')]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-11-5169d4e8baf6> in <module>
#       1 df=df.dropna(subset=['postal_code'])
# ----> 2 df[df.postal_code.str.contains('12866')]
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5459             or name in self._accessors
#    5460         ):
# -> 5461             return object.__getattribute__(self, name)
#    5462         else:
#    5463             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#
# ~\anaconda3\lib\site-packages\pandas\core\accessor.py in __get__(self, obj, cls)
#     178             # we're accessing the attribute of the class, i.e., Dataset.geo
#     179             return self._accessor
# --> 180         accessor_obj = self._accessor(obj)
#     181         # Replace the property with the accessor object. Inspired by:
# ...

# %%
df[df['postal_code']]

# %%
df.dtypes

# %%
var="saratoga springs, ny"
data=df[df['zip_name']==var]
y='median_listing_price_per_square_foot'

sns.lineplot(data=data,x='date',y=y,hue='zip_name',)
fig = mpl.pyplot.gcf()
fig.set_size_inches(15,9.5)
plt.xticks(rotation=60)
plt.title("Realtor.com " + y)
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)

# %%
#pip freeze
